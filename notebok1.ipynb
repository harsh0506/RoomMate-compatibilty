# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df.head(2)
# Out:
#    id  roomsharingprefrence yourgender genderpref      budget agerange  \
# 0   1                  True       Male       Male  5000-10000    20-25
# 1   2                  True     Female      Other  5000-10000    25-30
#
#                  friendshipchoice                    personalitytrait  \
# 0  Yes, I\m looking for a friend.  Compatibility in Tastes and Habits
# 1  Yes, I'm looking for a friend.  Compatibility in Tastes and Habits
#
#      dailyroutine roommatesdailyroutine  ... moviepref       citipref  \
# 0  morning person                  Both  ...    Comedy         Mumbai
# 1    night person               Morning  ...    Comedy  Greater Noida
#
#                                          cleanliness skillscookclean  \
# 0  I\m diligent about cleaning and enjoy maintain...               3
# 1  I'm diligent about cleaning and enjoy maintain...               3
#
#                          comforwithcompany  \
# 0  I enjoy company and having people over.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10002 entries, 0 to 10001
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     10002 non-null  int64
#  1   roomsharingprefrence   10002 non-null  bool
#  2   yourgender             10002 non-null  object
#  3   genderpref             10002 non-null  object
#  4   budget                 10002 non-null  object
#  5   agerange               10002 non-null  object
#  6   friendshipchoice       10002 non-null  object
#  7   personalitytrait       10002 non-null  object
#  8   dailyroutine           10002 non-null  object
#  9   roommatesdailyroutine  10002 non-null  object
#  10  dietrypref             10002 non-null  object
#  11  personality            10002 non-null  object
#  12  socialstatus           10002 non-null  object
#  13  youroccup              10002 non-null  object
# ...
